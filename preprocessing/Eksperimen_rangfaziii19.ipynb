# %% [markdown]
# # **1. Perkenalan Dataset**
# Dataset ini adalah Telco Customer Churn dari Kaggle. Dataset ini berisi data pelanggan perusahaan telekomunikasi dan digunakan untuk memprediksi apakah pelanggan akan berhenti berlangganan (churn) atau tidak.

# %% [markdown]
# # **2. Import Library**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # **3. Memuat Dataset**

# %%
# Memuat dataset dari folder root
df = pd.read_csv('../churn_dataset_raw.csv')
df.head()

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**

# %%
df.info()
print("\nJumlah nilai kosong:\n", df.isnull().sum())
print("\nDistribusi label Churn:\n", df['Churn'].value_counts())

# %% [markdown]
# # **5. Data Preprocessing**
# Mengisi nilai kosong, menghapus kolom tidak relevan, dan melakukan encoding.

# %%
# Hapus customerID
if 'customerID' in df.columns:
    df = df.drop('customerID', axis=1)

# Ubah TotalCharges ke numerik dan isi nilai kosong
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# Encoding data kategorikal
categorical_columns = df.select_dtypes(include=['object']).columns
le = LabelEncoder()
for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

# Simpan data hasil preprocessing
df.to_csv('churn_preprocessing.csv', index=False)
print("Data berhasil disimpan ke churn_preprocessing.csv")
