# %% [markdown]
# # Eksperimen Sistem Machine Learning
# Nama: Rangga
# Dataset: Telco Customer Churn (Kaggle)
# Tujuan: Membangun model prediksi *customer churn* dengan Random Forest.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %%
# Load raw dataset (we go one folder up because this notebook is inside 'preprocessing' folder)
df = pd.read_csv('../churn_dataset_raw.csv')
df.head()

# %%
df.info()

# %% [markdown]
# ## 2. Preprocessing Data

# %%
# Drop customerID as it's not useful
if 'customerID' in df.columns:
    df = df.drop('customerID', axis=1)

# Fix empty spaces in TotalCharges
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# Encode Categorical Variables
categorical_columns = df.select_dtypes(include=['object']).columns
le = LabelEncoder()
for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

df.head()

# %% [markdown]
# ## 3. Menyimpan Data Bersih

# %%
df.to_csv('churn_preprocessing.csv', index=False)
print("Data berhasil disimpan ke churn_preprocessing.csv")
